# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import CurveStyle, MermaidDrawMethod
from src.langgraph.main import create_app

app = create_app()

display(
    Image(
        app.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)
# Out:
# agiflow.agiflow::Agiflow exporting traces to http://localhost:8081 authenticating with bearer token
# ## Welcome to the Product Agents
# -------------------------------

# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import CurveStyle, MermaidDrawMethod
from src.langgraph_ops.main import create_app

app = create_app()

display(
    Image(
        app.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)
# Out:
# agiflow.agiflow::Agiflow exporting traces to http://localhost:8081 authenticating with bearer token
# ## Welcome to the Product Agents
# -------------------------------
